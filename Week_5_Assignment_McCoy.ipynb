# %% [markdown]
# # DS Automation Assignment

# %% [markdown]
# Using our prepared churn data from week 2:
# - use pycaret to find an ML algorithm that performs best on the data
#     - Choose a metric you think is best to use for finding the best model; by default, it is accuracy but it could be AUC, precision, recall, etc. The week 3 FTE has some information on these different metrics.
# - save the model to disk
# - create a Python script/file/module with a function that takes a pandas dataframe as an input and returns the probability of churn for each row in the dataframe
#     - your Python file/function should print out the predictions for new data (new_churn_data.csv)
#     - the true values for the new data are [1, 0, 0, 1, 0] if you're interested
# - test your Python module and function with the new data, new_churn_data.csv
# - write a short summary of the process and results at the end of this notebook
# - upload this Jupyter Notebook and Python file to a Github repository, and turn in a link to the repository in the week 5 assignment dropbox
#
# *Optional* challenges:
# - return the probability of churn for each new prediction, and the percentile where that prediction is in the distribution of probability predictions from the training dataset (e.g. a high probability of churn like 0.78 might be at the 90th percentile)
# - use other autoML packages, such as TPOT, H2O, MLBox, etc, and compare performance and features with pycaret
# - create a class in your Python module to hold the functions that you created
# - accept user input to specify a file using a tool such as Python's `input()` function, the `click` package for command-line arguments, or a GUI
# - Use the unmodified churn data (new_unmodified_churn_data.csv) in your Python script. This will require adding the same preprocessing steps from week 2 since this data is like the original unmodified dataset from week 1.

# %%
# !pip install pycaret
# Out:
# Requirement already satisfied: pycaret in c:\users\b\appdata\roaming\python\python38\site-packages (2.3.10)
# Requirement already satisfied: kmodes>=0.10.1 in c:\users\b\appdata\roaming\python\python38\site-packages (from pycaret) (0.12.2)
# Requirement already satisfied: pandas-profiling>=2.8.0 in c:\users\b\appdata\roaming\python\python38\site-packages (from pycaret) (3.4.0)
# Requirement already satisfied: scikit-plot in c:\users\b\appdata\roaming\python\python38\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: pyyaml<6.0.0 in c:\users\b\appdata\roaming\python\python38\site-packages (from pycaret) (5.4.1)
# Requirement already satisfied: spacy<2.4.0 in c:\users\b\appdata\roaming\python\python38\site-packages (from pycaret) (2.3.8)
# Requirement already satisfied: cufflinks>=0.17.0 in c:\users\b\appdata\roaming\python\python38\site-packages (from pycaret) (0.17.3)
# Requirement already satisfied: yellowbrick>=1.0.1 in c:\users\b\appdata\roaming\python\python38\site-packages (from pycaret) (1.2.1)
# Requirement already satisfied: pandas in c:\users\b\anaconda3\envs\week5\lib\site-packages (from pycaret) (1.5.1)
# Requirement already satisfied: gensim<4.0.0 in c:\users\b\appdata\roaming\python\python38\site-packages (from pycaret) (3.8.3)
# Requirement already satisfied: plotly>=4.4.1 in c:\users\b\appdata\roaming\python\python38\site-packages (from pycaret) (5.11.0)
# Requirement already satisfied: lightgbm>=2.3.1 in c:\users\b\appdata\roaming\python\python38\site-packages (from pycaret) (3.3.3)
# Requirement already satisfied: scikit-learn==0.23.2 in c:\users\b\appdata\roaming\python\python38\site-packages (from pycaret) (0.23.2)
# Requirement already satisfied: umap-learn in c:\users\b\appdata\roaming\python\python38\site-packages (from pycaret) (0.5.3)
# Requirement already satisfied: ipywidgets in c:\users\b\appdata\roaming\python\python38\site-packages (from pycaret) (8.0.2)
# Requirement already satisfied: mlflow in c:\users\b\appdata\roaming\python\python38\site-packages (from pycaret) (2.0.1)
# Requirement already satisfied: pyod in c:\users\b\appdata\roaming\python\python38\site-packages (from pycaret) (1.0.6)
# Requirement already satisfied: IPython in c:\users\b\anaconda3\envs\week5\lib\site-packages (from pycaret) (8.6.0)
# Requirement already satisfied: scipy<=1.5.4 in c:\users\b\appdata\roaming\python\python38\site-packages (from pycaret) (1.5.4)
# Requirement already satisfied: joblib in c:\users\b\appdata\roaming\python\python38\site-packages (from pycaret) (1.2.0)
# Requirement already satisfied: textblob in c:\users\b\appdata\roaming\python\python38\site-packages (from pycaret) (0.17.1)
# Requirement already satisfied: mlxtend>=0.17.0 in c:\users\b\appdata\roaming\python\python38\site-packages (from pycaret) (0.19.0)
# Requirement already satisfied: wordcloud in c:\users\b\appdata\roaming\python\python38\site-packages (from pycaret) (1.8.2.2)
# Requirement already satisfied: matplotlib in c:\users\b\appdata\roaming\python\python38\site-packages (from pycaret) (3.5.3)
# Requirement already satisfied: imbalanced-learn==0.7.0 in c:\users\b\appdata\roaming\python\python38\site-packages (from pycaret) (0.7.0)
# Requirement already satisfied: seaborn in c:\users\b\appdata\roaming\python\python38\site-packages (from pycaret) (0.12.1)
# Requirement already satisfied: numba<0.55 in c:\users\b\appdata\roaming\python\python38\site-packages (from pycaret) (0.54.1)
# Requirement already satisfied: nltk in c:\users\b\appdata\roaming\python\python38\site-packages (from pycaret) (3.7)
# Requirement already satisfied: Boruta in c:\users\b\appdata\roaming\python\python38\site-packages (from pycaret) (0.3)
# Requirement already satisfied: pyLDAvis in c:\users\b\appdata\roaming\python\python38\site-packages (from pycaret) (3.3.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\b\appdata\roaming\python\python38\site-packages (from imbalanced-learn==0.7.0->pycaret) (1.20.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\b\appdata\roaming\python\python38\site-packages (from scikit-learn==0.23.2->pycaret) (3.1.0)
# Requirement already satisfied: setuptools>=34.4.1 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from cufflinks>=0.17.0->pycaret) (65.5.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from cufflinks>=0.17.0->pycaret) (1.16.0)
# Requirement already satisfied: colorlover>=0.2.1 in c:\users\b\appdata\roaming\python\python38\site-packages (from cufflinks>=0.17.0->pycaret) (0.3.0)
# Requirement already satisfied: Cython==0.29.14 in c:\users\b\appdata\roaming\python\python38\site-packages (from gensim<4.0.0->pycaret) (0.29.14)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\b\appdata\roaming\python\python38\site-packages (from gensim<4.0.0->pycaret) (6.2.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from IPython->pycaret) (2.11.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from IPython->pycaret) (3.0.20)
# Requirement already satisfied: colorama in c:\users\b\anaconda3\envs\week5\lib\site-packages (from IPython->pycaret) (0.4.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from IPython->pycaret) (0.18.1)
# Requirement already satisfied: backcall in c:\users\b\anaconda3\envs\week5\lib\site-packages (from IPython->pycaret) (0.2.0)
# Requirement already satisfied: stack-data in c:\users\b\anaconda3\envs\week5\lib\site-packages (from IPython->pycaret) (0.2.0)
# Requirement already satisfied: matplotlib-inline in c:\users\b\anaconda3\envs\week5\lib\site-packages (from IPython->pycaret) (0.1.6)
# Requirement already satisfied: traitlets>=5 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from IPython->pycaret) (5.1.1)
# Requirement already satisfied: decorator in c:\users\b\anaconda3\envs\week5\lib\site-packages (from IPython->pycaret) (5.1.1)
# Requirement already satisfied: pickleshare in c:\users\b\anaconda3\envs\week5\lib\site-packages (from IPython->pycaret) (0.7.5)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\b\appdata\roaming\python\python38\site-packages (from ipywidgets->pycaret) (4.0.3)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from ipywidgets->pycaret) (6.15.2)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\b\appdata\roaming\python\python38\site-packages (from ipywidgets->pycaret) (3.0.3)
# Requirement already satisfied: wheel in c:\users\b\anaconda3\envs\week5\lib\site-packages (from lightgbm>=2.3.1->pycaret) (0.37.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\b\appdata\roaming\python\python38\site-packages (from matplotlib->pycaret) (4.38.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from matplotlib->pycaret) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from matplotlib->pycaret) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\b\appdata\roaming\python\python38\site-packages (from matplotlib->pycaret) (9.3.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\b\appdata\roaming\python\python38\site-packages (from matplotlib->pycaret) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from matplotlib->pycaret) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\b\appdata\roaming\python\python38\site-packages (from matplotlib->pycaret) (0.11.0)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in c:\users\b\appdata\roaming\python\python38\site-packages (from numba<0.55->pycaret) (0.37.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from pandas->pycaret) (2022.1)
# Requirement already satisfied: requests<2.29,>=2.24.0 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (2.28.1)
# Requirement already satisfied: multimethod<1.10,>=1.4 in c:\users\b\appdata\roaming\python\python38\site-packages (from pandas-profiling>=2.8.0->pycaret) (1.9)
# Requirement already satisfied: statsmodels<0.14,>=0.13.2 in c:\users\b\appdata\roaming\python\python38\site-packages (from pandas-profiling>=2.8.0->pycaret) (0.13.5)
# Requirement already satisfied: missingno<0.6,>=0.4.2 in c:\users\b\appdata\roaming\python\python38\site-packages (from pandas-profiling>=2.8.0->pycaret) (0.5.1)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in c:\users\b\appdata\roaming\python\python38\site-packages (from pandas-profiling>=2.8.0->pycaret) (0.7.5)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\b\appdata\roaming\python\python38\site-packages (from pandas-profiling>=2.8.0->pycaret) (0.12.2)
# Requirement already satisfied: pydantic<1.11,>=1.8.1 in c:\users\b\appdata\roaming\python\python38\site-packages (from pandas-profiling>=2.8.0->pycaret) (1.10.2)
# Requirement already satisfied: tqdm<4.65,>=4.48.2 in c:\users\b\appdata\roaming\python\python38\site-packages (from pandas-profiling>=2.8.0->pycaret) (4.64.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (3.1.2)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\b\appdata\roaming\python\python38\site-packages (from pandas-profiling>=2.8.0->pycaret) (0.1.12)
# Requirement already satisfied: networkx>=2.4 in c:\users\b\appdata\roaming\python\python38\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling>=2.8.0->pycaret) (2.8.8)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in c:\users\b\appdata\roaming\python\python38\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling>=2.8.0->pycaret) (0.2.0)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling>=2.8.0->pycaret) (22.1.0)
# Requirement already satisfied: imagehash in c:\users\b\appdata\roaming\python\python38\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling>=2.8.0->pycaret) (4.3.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\b\appdata\roaming\python\python38\site-packages (from plotly>=4.4.1->pycaret) (8.1.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\b\appdata\roaming\python\python38\site-packages (from spacy<2.4.0->pycaret) (2.0.7)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in c:\users\b\appdata\roaming\python\python38\site-packages (from spacy<2.4.0->pycaret) (1.0.6)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in c:\users\b\appdata\roaming\python\python38\site-packages (from spacy<2.4.0->pycaret) (1.0.2)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in c:\users\b\appdata\roaming\python\python38\site-packages (from spacy<2.4.0->pycaret) (7.4.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\b\appdata\roaming\python\python38\site-packages (from spacy<2.4.0->pycaret) (0.7.9)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from spacy<2.4.0->pycaret) (0.10.1)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\users\b\appdata\roaming\python\python38\site-packages (from spacy<2.4.0->pycaret) (1.1.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\b\appdata\roaming\python\python38\site-packages (from spacy<2.4.0->pycaret) (1.0.9)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\b\appdata\roaming\python\python38\site-packages (from spacy<2.4.0->pycaret) (3.0.8)
# Requirement already satisfied: shap<1,>=0.40 in c:\users\b\appdata\roaming\python\python38\site-packages (from mlflow->pycaret) (0.41.0)
# Requirement already satisfied: entrypoints<1 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from mlflow->pycaret) (0.4)
# Requirement already satisfied: docker<7,>=4.0.0 in c:\users\b\appdata\roaming\python\python38\site-packages (from mlflow->pycaret) (6.0.1)
# Requirement already satisfied: sqlalchemy<2,>=1.4.0 in c:\users\b\appdata\roaming\python\python38\site-packages (from mlflow->pycaret) (1.4.44)
# Requirement already satisfied: gitpython<4,>=2.1.0 in c:\users\b\appdata\roaming\python\python38\site-packages (from mlflow->pycaret) (3.1.29)
# Requirement already satisfied: importlib-metadata!=4.7.0,<6,>=3.7.0 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from mlflow->pycaret) (4.11.3)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\b\appdata\roaming\python\python38\site-packages (from mlflow->pycaret) (3.4.1)
# Requirement already satisfied: protobuf<5,>=3.12.0 in c:\users\b\appdata\roaming\python\python38\site-packages (from mlflow->pycaret) (4.21.9)
# Requirement already satisfied: querystring-parser<2 in c:\users\b\appdata\roaming\python\python38\site-packages (from mlflow->pycaret) (1.2.4)
# Requirement already satisfied: pyarrow<11,>=4.0.0 in c:\users\b\appdata\roaming\python\python38\site-packages (from mlflow->pycaret) (10.0.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\b\appdata\roaming\python\python38\site-packages (from mlflow->pycaret) (8.1.3)
# Requirement already satisfied: waitress<3 in c:\users\b\appdata\roaming\python\python38\site-packages (from mlflow->pycaret) (2.1.2)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\b\appdata\roaming\python\python38\site-packages (from mlflow->pycaret) (0.4.3)
# Requirement already satisfied: alembic<2 in c:\users\b\appdata\roaming\python\python38\site-packages (from mlflow->pycaret) (1.8.1)
# Requirement already satisfied: databricks-cli<1,>=0.8.7 in c:\users\b\appdata\roaming\python\python38\site-packages (from mlflow->pycaret) (0.17.3)
# Requirement already satisfied: cloudpickle<3 in c:\users\b\appdata\roaming\python\python38\site-packages (from mlflow->pycaret) (2.2.0)
# Requirement already satisfied: Flask<3 in c:\users\b\appdata\roaming\python\python38\site-packages (from mlflow->pycaret) (2.2.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\b\appdata\roaming\python\python38\site-packages (from nltk->pycaret) (2022.10.31)
# Requirement already satisfied: funcy in c:\users\b\appdata\roaming\python\python38\site-packages (from pyLDAvis->pycaret) (1.17)
# Requirement already satisfied: numexpr in c:\users\b\appdata\roaming\python\python38\site-packages (from pyLDAvis->pycaret) (2.8.4)
# Requirement already satisfied: sklearn in c:\users\b\anaconda3\envs\week5\lib\site-packages (from pyLDAvis->pycaret) (0.0.post1)
# Requirement already satisfied: future in c:\users\b\appdata\roaming\python\python38\site-packages (from pyLDAvis->pycaret) (0.18.2)
# Requirement already satisfied: pynndescent>=0.5 in c:\users\b\appdata\roaming\python\python38\site-packages (from umap-learn->pycaret) (0.5.8)
# Requirement already satisfied: importlib-resources in c:\users\b\anaconda3\envs\week5\lib\site-packages (from alembic<2->mlflow->pycaret) (5.2.0)
# Requirement already satisfied: Mako in c:\users\b\appdata\roaming\python\python38\site-packages (from alembic<2->mlflow->pycaret) (1.2.4)
# Requirement already satisfied: tabulate>=0.7.7 in c:\users\b\appdata\roaming\python\python38\site-packages (from databricks-cli<1,>=0.8.7->mlflow->pycaret) (0.9.0)
# Requirement already satisfied: oauthlib>=3.1.0 in c:\users\b\appdata\roaming\python\python38\site-packages (from databricks-cli<1,>=0.8.7->mlflow->pycaret) (3.2.2)
# Requirement already satisfied: pyjwt>=1.7.0 in c:\users\b\appdata\roaming\python\python38\site-packages (from databricks-cli<1,>=0.8.7->mlflow->pycaret) (2.6.0)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from docker<7,>=4.0.0->mlflow->pycaret) (0.58.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from docker<7,>=4.0.0->mlflow->pycaret) (1.26.12)
# Requirement already satisfied: pywin32>=304 in c:\users\b\appdata\roaming\python\python38\site-packages (from docker<7,>=4.0.0->mlflow->pycaret) (305)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\b\appdata\roaming\python\python38\site-packages (from Flask<3->mlflow->pycaret) (2.1.2)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\b\appdata\roaming\python\python38\site-packages (from Flask<3->mlflow->pycaret) (2.2.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\b\appdata\roaming\python\python38\site-packages (from gitpython<4,>=2.1.0->mlflow->pycaret) (4.0.9)
# Requirement already satisfied: zipp>=0.5 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from importlib-metadata!=4.7.0,<6,>=3.7.0->mlflow->pycaret) (3.8.0)
# Requirement already satisfied: debugpy>=1.0 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (1.6.3)
# Requirement already satisfied: nest-asyncio in c:\users\b\anaconda3\envs\week5\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (1.5.5)
# Requirement already satisfied: psutil in c:\users\b\anaconda3\envs\week5\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (5.9.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (23.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (7.3.5)
# Requirement already satisfied: tornado>=6.1 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (6.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from jedi>=0.16->IPython->pycaret) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from jinja2<3.2,>=2.11.1->pandas-profiling>=2.8.0->pycaret) (2.1.1)
# Requirement already satisfied: wcwidth in c:\users\b\anaconda3\envs\week5\lib\site-packages (from prompt-toolkit<3.1.0,>3.0.1->IPython->pycaret) (0.2.5)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from pydantic<1.11,>=1.8.1->pandas-profiling>=2.8.0->pycaret) (4.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from requests<2.29,>=2.24.0->pandas-profiling>=2.8.0->pycaret) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from requests<2.29,>=2.24.0->pandas-profiling>=2.8.0->pycaret) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from requests<2.29,>=2.24.0->pandas-profiling>=2.8.0->pycaret) (2.0.4)
# Requirement already satisfied: slicer==0.0.7 in c:\users\b\appdata\roaming\python\python38\site-packages (from shap<1,>=0.40->mlflow->pycaret) (0.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\b\appdata\roaming\python\python38\site-packages (from sqlalchemy<2,>=1.4.0->mlflow->pycaret) (2.0.1)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\b\appdata\roaming\python\python38\site-packages (from statsmodels<0.14,>=0.13.2->pandas-profiling>=2.8.0->pycaret) (0.5.3)
# Requirement already satisfied: executing in c:\users\b\anaconda3\envs\week5\lib\site-packages (from stack-data->IPython->pycaret) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\b\anaconda3\envs\week5\lib\site-packages (from stack-data->IPython->pycaret) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\b\anaconda3\envs\week5\lib\site-packages (from stack-data->IPython->pycaret) (0.2.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\b\appdata\roaming\python\python38\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow->pycaret) (5.0.0)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\b\anaconda3\envs\week5\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->pycaret) (4.11.2)
# Requirement already satisfied: PyWavelets in c:\users\b\appdata\roaming\python\python38\site-packages (from imagehash->visions[type_image_path]==0.7.5->pandas-profiling>=2.8.0->pycaret) (1.4.1)

# %%
import pandas as pd
from pycaret.classification import setup, compare_models, predict_model, save_model, load_model

# %%
df = pd.read_csv('prepped_churn_data.csv')
df = df.drop("customerID", axis = 'columns')
df
# Out:
#       Unnamed: 0  tenure  PhoneService  Contract  PaymentMethod  \
# 0              0       1             1         0              0
# 1              1      34             0         1              1
# 2              2       2             0         0              1
# 3              3      45             1         1              2
# 4              4       2             0         0              0
# ...          ...     ...           ...       ...            ...
# 7027        7038      24             0         1              1
# 7028        7039      72             0         1              3
# 7029        7040      11             1         0              0
# 7030        7041       4             0         0              1
# 7031        7042      66             0         2              2
#
#       MonthlyCharges  TotalCharges  Churn  TCharges_tenure_ratio  \
# 0              29.85         29.85      1              29.850000
# 1              56.95       1889.50      1              55.573529
# 2              53.85        108.15      0              54.075000
# 3              42.30       1840.75      1              40.905556
# 4              70.70        151.65      0              75.825000
# ...              ...           ...    ...                    ...
# 7027           84.80       1990.50      1              82.937500
# 7028          103.20       7362.90      1             102.262500
# 7029           29.60        346.45      1              31.495455
# 7030           74.40        306.60      0              76.650000
# 7031          105.65       6844.50      1             103.704545
#
#       MCharges_tenure_ratio
# 0                 29.850000
# 1                  1.675000
# 2                 26.925000
# 3                  0.940000
# 4                 35.350000
# ...                     ...
# 7027               3.533333
# 7028               1.433333
# 7029               2.690909
# 7030              18.600000
# 7031               1.600758
#
# [7032 rows x 10 columns]

# %%
automl = setup(data = df, target = 'Churn')
# Out:
# <style type="text/css">
# #T_462d2_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_462d2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_462d2_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_462d2_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_462d2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_462d2_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_462d2_row0_col1" class="data row0 col1" >586</td>
#     </tr>
#     <tr>
#       <th id="T_462d2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_462d2_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_462d2_row1_col1" class="data row1 col1" >Churn</td>
#     </tr>
#     <tr>
#       <th id="T_462d2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_462d2_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_462d2_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_462d2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_462d2_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_462d2_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_462d2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_462d2_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_462d2_row4_col1" class="data row4 col1" >(7032, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_462d2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_462d2_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_462d2_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_462d2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_462d2_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_462d2_row6_col1" class="data row6 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_462d2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_462d2_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_462d2_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_462d2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_462d2_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_462d2_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_462d2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_462d2_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_462d2_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_462d2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_462d2_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_462d2_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_462d2_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_462d2_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_462d2_row11_col1" class="data row11 col1" >(4922, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_462d2_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_462d2_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_462d2_row12_col1" class="data row12 col1" >(2110, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_462d2_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_462d2_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_462d2_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_462d2_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_462d2_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_462d2_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_462d2_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_462d2_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_462d2_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_462d2_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_462d2_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_462d2_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_462d2_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_462d2_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_462d2_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_462d2_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_462d2_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_462d2_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_462d2_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_462d2_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_462d2_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_462d2_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_462d2_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_462d2_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_462d2_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_462d2_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_462d2_row21_col1" class="data row21 col1" >9a32</td>
#     </tr>
#     <tr>
#       <th id="T_462d2_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_462d2_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_462d2_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_462d2_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_462d2_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_462d2_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_462d2_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_462d2_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_462d2_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_462d2_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_462d2_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_462d2_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_462d2_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_462d2_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_462d2_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_462d2_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_462d2_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_462d2_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_462d2_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_462d2_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_462d2_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_462d2_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_462d2_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_462d2_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_462d2_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_462d2_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_462d2_row30_col1" class="d

# %%
automl[6]
# Out:
# 'box-cox'

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_0d3e4 th {
#   text-align: left;
# }
# #T_0d3e4_row0_col0, #T_0d3e4_row0_col2, #T_0d3e4_row0_col3, #T_0d3e4_row0_col4, #T_0d3e4_row0_col5, #T_0d3e4_row0_col6, #T_0d3e4_row0_col7, #T_0d3e4_row1_col0, #T_0d3e4_row1_col1, #T_0d3e4_row1_col2, #T_0d3e4_row1_col3, #T_0d3e4_row1_col4, #T_0d3e4_row1_col6, #T_0d3e4_row1_col7, #T_0d3e4_row2_col0, #T_0d3e4_row2_col1, #T_0d3e4_row2_col3, #T_0d3e4_row2_col4, #T_0d3e4_row2_col5, #T_0d3e4_row2_col7, #T_0d3e4_row3_col0, #T_0d3e4_row3_col1, #T_0d3e4_row3_col2, #T_0d3e4_row3_col3, #T_0d3e4_row3_col4, #T_0d3e4_row3_col5, #T_0d3e4_row3_col6, #T_0d3e4_row3_col7, #T_0d3e4_row4_col0, #T_0d3e4_row4_col1, #T_0d3e4_row4_col2, #T_0d3e4_row4_col3, #T_0d3e4_row4_col4, #T_0d3e4_row4_col5,
>0.1260</td>
#     </tr>
#     <tr>
#       <th id="T_0d3e4_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_0d3e4_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_0d3e4_row5_col1" class="data row5 col1" >0.7820</td>
#       <td id="T_0d3e4_row5_col2" class="data row5 col2" >0.8231</td>
#       <td id="T_0d3e4_row5_col3" class="data row5 col3" >0.8874</td>
#       <td id="T_0d3e4_row5_col4" class="data row5 col4" >0.8288</td>
#       <td id="T_0d3e4_row5_col5" class="data row5 col5" >0.8570</td>
#       <td id="T_0d3e4_row5_col6" class="data row5 col6" >0.4004</td>
#       <td id="T_0d3e4_row5_col7" class="data row5 col7" >0.4056</td>

# %%
best_model
#looks like our best model is the LDA
# Out:
# LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                            solver='svd', store_covariance=False, tol=0.0001)

# %%
new_df = df.iloc[-2:-1].copy()
new_df.drop('Churn', axis = 1, inplace = True)
new_df
# Out:
#       Unnamed: 0  tenure  PhoneService  Contract  PaymentMethod  \
# 7030        7041       4             0         0              1
#
#       MonthlyCharges  TotalCharges  TCharges_tenure_ratio  \
# 7030            74.4         306.6                  76.65
#
#       MCharges_tenure_ratio
# 7030                   18.6

# %%
predict_model(best_model, new_df)
# Out:
#       Unnamed: 0  tenure  PhoneService  Contract  PaymentMethod  \
# 7030        7041       4             0         0              1
#
#       MonthlyCharges  TotalCharges  TCharges_tenure_ratio  \
# 7030            74.4         306.6                  76.65
#
#       MCharges_tenure_ratio  Label   Score
# 7030                   18.6      0  0.5319

# %%
#Saving and loading our model
save_model(best_model, 'LDA')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='Churn',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strate...
#                  ('dummy', Dummify(target='Churn')),
#                  ('fix_perfect', Remove_100(target='Churn')),
#                  ('clean_names', Clean_Colum_Names()),
#                  ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                  ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                  ['trained_model',
#                   LinearDiscriminantAnalysis(n_components=None, priors=None,
#                                              shrinkage=None, solver='svd',
#                                              store_covariance=False,
#                                              tol=0.0001)]],
#           verbose=False),
#  'LDA.pkl')

# %%
test_model = load_model('LDA')
predict_model(test_model,data= new_df)
# Out:
# Transformation Pipeline and Model Successfully Loaded
#       Unnamed: 0  tenure  PhoneService  Contract  PaymentMethod  \
# 7030        7041       4             0         0              1
#
#       MonthlyCharges  TotalCharges  TCharges_tenure_ratio  \
# 7030            74.4         306.6                  76.65
#
#       MCharges_tenure_ratio  Label   Score
# 7030                   18.6      0  0.5319

# %%
import pickle
with open ('LDA_model.pk', 'wb') as f:
    pickle.dump(best_model,f)
# we used built in function to open a file with the name LDA_model.pk, then opened it for writing (w) and in a binary
#format using b.
#save file object in variable f 
#with statement automatically closes the file

# %%
with open('LDA_model.pk', 'rb') as f: 
    loaded_model = pickle.load(f)
#reload data

# %%
from IPython.display import Code
Code('predict_churn.py')
# Out:
# predict_churn.py

# %%
# %run predict_churn.py

# %% [markdown]
# # Summary

# %% [markdown]
# Write a short summary of the process and results here.
#
# Pycaret was installed so that we can use this libary to import the functions we will use. The next line we imported those functions. Using the variable automl, the setup function will have us pass the target variable to inform the function that we will not train against a feature. The best model for this data set is LDA, linear discriminant analysis with an accuracy of 79.72%. A new data frame was created to drop the churn column. Then, we saved the model. Pickle is used to save and load binary data. We used this to open a file with the name LDA_model.py, then opened it for writing. Then, a file was created.
